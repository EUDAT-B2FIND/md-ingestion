# %%
import requests

graphql_query = """
{
  datasets(hasCitations: 1, query: "wdcc", first:135) {
    totalCount
    nodes {
      citationCount
      id
      titles {
      	title
      }
      repository { 
        name
      }
    }
  }
}
"""

graphql_payload = {
        "query": graphql_query}

graphql_url = "https://api.datacite.org/graphql"

headers = {
        "Content-Type": "application/json"
    }

def count_citations():
    response = requests.post(graphql_url, json=graphql_payload, headers=headers)
    if response.ok:
        result = response.json()
     #   print (result)
    else:
        print(response.text)
        result = None
    lookup_cit = {}
    if result:
        for record in result['data']['datasets']['nodes']:
            id = record['id']
            citationCount = record['citationCount']
            lookup_cit[id] = citationCount
    return lookup_cit

# %%
count_citations()
# Out:
# {'https://doi.org/10.1594/wdcc/clm_a1b_1_d2': 1,
#  'https://doi.org/10.1594/wdcc/clm_a1b_1_d3': 3,
#  'https://doi.org/10.1594/wdcc/clm_a1b_2_d3': 4,
#  'https://doi.org/10.1594/wdcc/clm_b1_1_d3': 1,
#  'https://doi.org/10.1594/wdcc/clm_b1_2_d3': 1,
#  'https://doi.org/10.1594/wdcc/clm_c20_1_d3': 3,
#  'https://doi.org/10.1594/wdcc/clm_c20_2_d3': 4,
#  'https://doi.org/10.1594/wdcc/dphase_prevah': 1,
#  'https://doi.org/10.1594/wdcc/dphase_qbolam11': 1,
#  'https://doi.org/10.1594/wdcc/eh4_opyc_sres_b2': 2,
#  'https://doi.org/10.1594/wdcc/eh5-t63l31_om-gr1.5_cmip4_1_6h': 1,
#  'https://doi.org/10.1594/wdcc/eh5-t63l31_om-gr1.5l40_ctl_6h': 1,
#  'https://doi.org/10.1594/wdcc/hoaps2_monthly': 1,
#  'https://doi.org/10.1594/wdcc/hoaps2_pentad': 1,
#  'https://doi.org/10.1594/wdcc/hoaps3_daily': 5,
#  'https://doi.org/10.1594/wdcc/hoaps3_monthly': 4,
#  'https://doi.org/10.1594/wdcc/hoaps3_pentad': 3,
#  'https://doi.org/10.1594/wdcc/ipcc_eh4_opyc_sres_a2_mm': 1,
#  'https://doi.org/10.1594/wdcc/recon_land_cover_800-1992': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.mxelpc': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.mxelhi': 2,
#  'https://doi.org/10.1594/wdcc/cmip5.mxelr2': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.mxelr4': 2,
#  'https://doi.org/10.1594/wdcc/cmip5.mxelr8': 3,
#  'https://doi.org/10.1594/wdcc/cmip5.mxeppc': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.mxeldec': 1,
#  'https://doi.org/10.1594/wdcc/coastdat-2_cosmo-clm': 2,
#  'https://doi.org/10.1594/wdcc/coastdat-2_trim-np-2d': 3,
#  'https://doi.org/10.1594/wdcc/cmip5.cmc2pc': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.nfcfhi': 1,
#  'https://doi.org/10.1594/wdcc/en_calipso_2006-2010': 1,
#  'https://doi.org/10.1594/wdcc/en_volcaniceruption_2000-2010': 1,
#  'https://doi.org/10.1594/wdcc/ethr4': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.gighhm': 1,
#  'https://doi.org/10.1594/wdcc/wrf_noah_buk_ger_top_soiltyp': 1,
#  'https://doi.org/10.1594/wdcc/wrf_noah_hwsd_world_top_soiltyp': 4,
#  'https://doi.org/10.1594/wdcc/cmip5.ngempc': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.mim7pc': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.mimhpc': 1,
#  'https://doi.org/10.1594/wdcc/clisap_mpi-esm-xr_t255l95': 2,
#  'https://doi.org/10.1594/wdcc/cmip5.ipila2': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilec': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilhg': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipils2': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilr4': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilaf': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilx2': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilmh': 2,
#  'https://doi.org/10.1594/wdcc/cmip5.ipillg': 2,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil80': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipileh': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilq4': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilhi': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil05': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilq2': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilhm': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilc2': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil90': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilpk': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilhn': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilc1': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilss': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil95': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil85': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipile8': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil60': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil75': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil65': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil70': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilx1': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilr2': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilsa': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilam': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilqc': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipile2': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilpc': 2,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilr8': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilr6': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipil00': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipilsc': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipila4': 1,
#  'https://doi.org/10.1594/wdcc/cmip5.ipile1': 1,
#  'https://doi.org/10.1594/wdcc/trim-np-2d-pca_rescurr': 1,
#  'https://doi.org/10.1594/wdcc/evolv2k_v1': 2,
#  'https://doi.org/10.1594/wdcc/chelsa_v1': 2,
#  'https://doi.org/10.1594/wdcc/chelsa_v1_1': 2,
#  'https://doi.org/10.1594/wdcc/ekf400_v1': 1,
#  'https://doi.org/10.1594/wdcc/wrf12_hadgem2_hist': 1,
#  'https://doi.org/10.1594/wdcc/nsbclim_v1.1': 3,
#  'https://doi.org/10.1594/wdcc/oceanrain-r': 1,
#  'https://doi.org/10.1594/wdcc/oceanrain-m': 1,
#  'https://doi.org/10.1594/wdcc/oceanrain-w': 1,
#  'https://doi.org/10.1594/wdcc/gome-evl_water_vapor_clim_v2.2': 1,
#  'https://doi.org/10.1594/wdcc/waghc_v1.0': 2,
#  'https://doi.org/10.1594/wdcc/ssirc_1': 2,
#  'https://doi.org/10.1594/wdcc/halo_measurements_4': 2,
#  'https://doi.org/10.1594/wdcc/earlinet_all_2000-2015': 1,
#  'https://doi.org/10.1594/wdcc/en_saharandust_2000-2015': 1,
#  'https://doi.org/10.1594/wdcc/emac-made3_12h': 1,
#  'https://doi.org/10.1594/wdcc/emac-made3_monthly': 1,
#  'https://doi.org/10.26050/wdcc/happi-global-echam6.3_v2': 7,
#  'https://doi.org/10.26050/wdcc/happi-global-cam4-2degree': 9,
#  'https://doi.org/10.26050/wdcc/happi-global-miroc5': 9,
#  'https://doi.org/10.26050/wdcc/bnsclimhydrov1.1': 1,
#  'https://doi.org/10.26050/wdcc/evolv2k_v3': 1,
#  'https://doi.org/10.26050/wdcc/rcm_cmip6_ssp245-hr': 1,
#  'https://doi.org/10.26050/wdcc/rcm_cmip6_ssp585-hr_r1i1p1f1': 1,
#  'https://doi.org/10.26050/wdcc/ekf400_v2.0': 2,
#  'https://doi.org/10.26050/wdcc/storm_tide_1906_20cr': 1,
#  'https://doi.org/10.26050/wdcc/storm_tide_1906_era-clim': 1,
#  'https://doi.org/10.26050/wdcc/storm_tide_1906_dwd_reconstruct': 1,
#  'https://doi.org/10.26050/wdcc/coastdat3_cosmo-clm_merra2': 1,
#  'https://doi.org/10.26050/wdcc/boxpol_unibonn_radar_5min_leve': 1,
#  'https://doi.org/10.26050/wdcc/luc_hist_landcovchange_v1.0': 1,
#  'https://doi.org/10.26050/wdcc/eobs_era5-river_runoff': 1,
#  'https://doi.org/10.26050/wdcc/ssirc_3': 1,
#  'https://doi.org/10.26050/wdcc/lookup-tables_for_transclim': 1,
#  'https://doi.org/10.26050/wdcc/volmip_pc': 1,
#  'https://doi.org/10.26050/wdcc/volmip_volc': 1,
#  'https://doi.org/10.26050/wdcc/gcos_ehi_1960-2020_ahc': 1,
#  'https://doi.org/10.26050/wdcc/gcos_ehi_1960-2020_crhc': 1,
#  'https://doi.org/10.26050/wdcc/gcos_ehi_1960-2020_iwhc': 1,
#  'https://doi.org/10.26050/wdcc/gcos_ehi_1960-2020_phc': 1,
#  'https://doi.org/10.26050/wdcc/c6scmawawm': 1,
#  'https://doi.org/10.26050/wdcc/c6sspawawm': 1,
#  'https://doi.org/10.26050/wdcc/uaicon_timesl_ctrl': 1,
#  'https://doi.org/10.26050/wdcc/uaicon_timesl_nonon': 1,
#  'https://doi.org/10.26050/wdcc/gcos_ehi_1960-2020_cohc_v2': 1,
#  'https://doi.org/10.26050/wdcc/gcos_ehi_1960-2020_ohc_v2': 1,
#  'https://doi.org/10.26050/wdcc/uaicon_timesl_nosso': 1,
#  'https://doi.org/10.26050/wdcc/pmmxmchtd': 1,
#  'https://doi.org/10.26050/wdcc/ar6.ipcc-ddc_ar6_sup_slpr': 3,
#  'https://doi.org/10.5281/zenodo.8051366': 1,
#  'https://doi.org/10.26050/wdcc/fesom14-recom2_a_hist_va_vc': 1,
#  'https://doi.org/10.26050/wdcc/fesom14-recom2_a_s585_va_vc': 1}
